# %%
import numpy as np
import pandas as pd
from datetime import datetime


from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
import lightgbm as lgb

from sklearn.metrics import mean_squared_error
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
data_tayara = pd.read_csv('/content/tayara_data.csv')

# %%
data_tayara
# Out:
#                                                   titre     prix  \
# 0                              pompe essence fiat panda    120.0
# 1                                          hyundai i 20  44000.0
# 2                                           GOLF 7 JOIN      1.0
# 3                                           peugeot 308  29000.0
# 4                                          Fiat 500 BVA     41.0
# ...                                                 ...      ...
# 8649                                      Fiat a vendre      0.0
# 8650  Av 3008 ehdi diesel boîte auto ttoption modèle...    102.0
# 8651                                         FORD FOCUS      0.0
# 8652                                            inthifa     34.0
# 8653                                          Chevrolet     29.0
#
#      gouvernerat et date dajout Kilométrage  \
# 0             Sfax , 4 days ago           2
# 1          Nabeul , a month ago       91000
# 2            Sfax , 12 days ago       47000
# ...

# %%
shape = data_tayara.shape
print(f"The shape of the dataframe is {shape[0]} rows and {shape[1]} columns")
# Out:
# The shape of the dataframe is 8654 rows and 15 columns

# %%
data_tayara.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8654 entries, 0 to 8653
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   titre                       8654 non-null   object
#  1   prix                        8654 non-null   float64
#  2   gouvernerat et date dajout  8654 non-null   object
#  3   Kilométrage                 8654 non-null   object
#  4   Couleur du véhicule         8654 non-null   object
#  5   Boite                       7644 non-null   object
#  6   Année                       7419 non-null   object
#  7   Cylindrée                   7410 non-null   object
#  8   Marque                      7392 non-null   object
#  9   Modèle                      6650 non-null   object
#  10  Puissance fiscale           6637 non-null   object
#  11  Type de carrosserie         6602 non-null   object
#  12  Carburant                   6562 non-null   object
# ...

# %%
data_tayara.isna().sum()
# Out:
# titre                            0
# prix                             0
# gouvernerat et date dajout       0
# Kilométrage                      0
# Couleur du véhicule              0
# Boite                         1010
# Année                         1235
# Cylindrée                     1244
# Marque                        1262
# Modèle                        2004
# Puissance fiscale             2017
# Type de carrosserie           2052
# Carburant                     2092
# Number of Pictures            2125
# Description                   2185
# dtype: int64

# %%
null_columns = data_tayara.columns[data_tayara.isna().mean() > 0.25]
data_automobile = data_tayara.drop(null_columns, axis=1)

# %%
null_columns
# Out:
# Index(['Description'], dtype='object')

# %%
data_tayara.isna().sum()
# Out:
# titre                            0
# prix                             0
# gouvernerat et date dajout       0
# Kilométrage                      0
# Couleur du véhicule              0
# Boite                         1010
# Année                         1235
# Cylindrée                     1244
# Marque                        1262
# Modèle                        2004
# Puissance fiscale             2017
# Type de carrosserie           2052
# Carburant                     2092
# Number of Pictures            2125
# Description                   2185
# dtype: int64

# %%
#data_tayara.drop('Number of Pictures'	, axis=1)

# %%
{column: len(data_automobile[column].unique()) for column in data_automobile.columns if data_automobile.dtypes[column] == 'object'}
